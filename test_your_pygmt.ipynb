# %%
import pygmt
pygmt.show_versions()

fig = pygmt.Figure()
fig.coast(region="g", frame=True, shorelines=1)
fig.show()
# Out:
# PyGMT information:
#   version: v0.11.0
# System information:
#   python: 3.12.2 | packaged by conda-forge | (main, Feb 16 2024, 20:50:58) [GCC 12.3.0]
#   executable: /home/abelem/miniforge3/envs/pygmt/bin/python
#   machine: Linux-6.5.0-26-generic-x86_64-with-glibc2.35
# Dependency information:
#   numpy: 1.26.4
#   pandas: 2.2.1
#   xarray: 2024.3.0
#   netCDF4: 1.6.5
#   packaging: 24.0
#   contextily: 1.6.0
#   geopandas: 0.14.3
#   ipython: None
#   rioxarray: 0.15.3
#   ghostscript: 10.03.0
# GMT library information:
#   binary version: 6.5.0
#   cores: 16
#   grid layout: rows
#   image layout:
#   library path: /home/abelem/miniforge3/envs/pygmt/lib/libgmt.so
#   padding: 2
#   plugin dir: /home/abelem/miniforge3/envs/pygmt/lib/gmt/plugins
#   share dir: /home/abelem/miniforge3/envs/pygmt/share/gmt
#   version: 6.5.0
